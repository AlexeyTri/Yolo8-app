# %% [markdown]
# <a href="https://colab.research.google.com/github/AlexeyTri/Yolo8-app/blob/main/Yolo_learn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !unzip /content/drive/MyDrive/ConstructionSafety.zip -d dataset_Yolo

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

# %%
# !yolo task=detect mode=predict model=yolov8l.pt conf=0.25 source='/content/Автомобильный_кран_Железнодорожных_войск_РФ.png'
# Out:
# ...
# 100% 83.7M/83.7M [00:01<00:00, 55.5MB/s]
# Ultralytics YOLOv8.0.57 🚀 Python-3.9.16 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8l summary (fused): 268 layers, 43668288 parameters, 0 gradients, 165.2 GFLOPs
#
# image 1/1 /content/Автомобильный_кран_Железнодорожных_войск_РФ.png: 448x640 1 person, 2 trucks, 50.6ms
# Speed: 0.6ms preprocess, 50.6ms inference, 48.8ms postprocess per image at shape (1, 3, 640, 640)

# %%
# !yolo task=detect mode=train model=yolov8l.pt data='/content/dataset_Yolo/data.yaml' epochs=50 imgsz=640
# Out:
# Ultralytics YOLOv8.0.57 🚀 Python-3.9.16 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
# ...
